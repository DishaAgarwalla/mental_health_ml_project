# %%
import pandas as pd

df = pd.read_csv("../data/Combined Data.csv")

df.head()
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety

# %%
df = df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = df.drop(columns=["Unnamed: 0"])
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
import os
print(os.getcwd())
# Out:
# e:\mental_health_ml_project\notebooks

# %%
import os

print("Current Directory:", os.getcwd())
print("Files in current folder:", os.listdir())
print("Files in parent folder:", os.listdir(".."))
print("Files inside data folder:", os.listdir("../data"))
# Out:
# Current Directory: e:\mental_health_ml_project\notebooks
# Files in current folder: ['exploration.ipynb']
# Files in parent folder: ['data', 'model', 'notebooks', 'README.md', 'src', 'venv']
# Files inside data folder: ['Combined Data.csv']

# %%
import pandas as pd

df = pd.read_csv("../data/Combined Data.csv")

df.head()
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety

# %%
df.info()
df["status"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53043 entries, 0 to 53042
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53043 non-null  int64
#  1   statement   52681 non-null  str
#  2   status      53043 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 1.2 MB
# status
# Normal                  16351
# Depression              15404
# Suicidal                10653
# Anxiety                  3888
# Bipolar                  2877
# Stress                   2669
# Personality disorder     1201
# Name: count, dtype: int64

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df = df.dropna(subset=["statement"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 52681 entries, 0 to 53042
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   statement  52681 non-null  str
#  1   status     52681 non-null  str
# dtypes: str(2)
# memory usage: 1.2 MB

# %%
df["status_binary"] = df["status"].apply(lambda x: 0 if x == "Normal" else 1)

df["status_binary"].value_counts()
# Out:
# status_binary
# 1    36338
# 0    16343
# Name: count, dtype: int64

# %%
X = df["statement"]
y = df["status_binary"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X = df["statement"]
#       2 y = df["status_binary"]
#
# NameError: name 'df' is not defined

# %%
X = df["statement"]
y = df["status_binary"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\mental_health_ml_project\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'status_binary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 X = df["statement"]
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'statement', 'status'], dtype='str')

# %%
df["status_binary"] = df["status"].map({
    "depressed": 1,
    "not depressed": 0
})

# %%
X = df["statement"]
y = df["status_binary"]
